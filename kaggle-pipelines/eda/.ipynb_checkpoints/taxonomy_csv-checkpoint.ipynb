# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
train = pd.read_csv(Path("/home/legionlinux/miniconda3/envs/torchenv/__INIT__/Kaggle/birdclef-2026/data/raw/train.csv"))
taxonomy = pd.read_csv(Path("/home/legionlinux/miniconda3/envs/torchenv/__INIT__/Kaggle/birdclef-2026/data/raw/taxonomy.csv"))

# %%
taxonomy
# Out:
#     primary_label  inat_taxon_id           scientific_name  \
# 0         1161364        1161364              Guyalna cuta
# 1          116570         116570             Caiman yacare
# 2         1176823        1176823    Leptodactylus luctator
# 3         1491113        1491113         Adenomera guarani
# 4         1595929        1595929         Lysapsus limellum
# ..            ...            ...                       ...
# 229       yebela1          16714       Elaenia flavogaster
# 230        yecmac          73272      Primolius auricollis
# 231        yecpar          19215        Brotogeris chiriri
# 232       yehcar1        1432779       Daptrius chimachima
# 233       yeofly1          16567  Tolmomyias sulphurescens
#
#                     common_name class_name
# 0                  Guyalna cuta    Insecta
# 1    Southern Spectacled Caiman   Reptilia
# 2                 Wrestler Frog   Amphibia
# 3      Guaraní leaf-litter frog   Amphibia
# ...

# %%
taxonomy[~taxonomy['primary_label'].isin(train['primary_label'])]
# Out:
#    primary_label  inat_taxon_id       scientific_name  \
# 3        1491113        1491113     Adenomera guarani
# 23         25073          25073  Chiasmocleis mehelyi
# 30    47158son01          47158          Insect son01
# 31    47158son02          47158          Insect son02
# 32    47158son03          47158          Insect son03
# 33    47158son04          47158          Insect son04
# 34    47158son05          47158          Insect son05
# 35    47158son06          47158          Insect son06
# 36    47158son07          47158          Insect son07
# 37    47158son08          47158          Insect son08
# 38    47158son09          47158          Insect son09
# 39    47158son10          47158          Insect son10
# 40    47158son11          47158          Insect son11
# 41    47158son12          47158          Insect son12
# 42    47158son13          47158          Insect son13
# 43    47158son14          47158          Insect son14
# ...
